# %% [markdown]
# ## Exercises I
# Run python -m pip install pymysql from your terminal to install pymysql.
#
# Create a notebook or python script named advanced_dataframes to do your work in for these exercises.

# %% [markdown]
# 1. Run python -m pip install pymysql from your terminal to install the mysql client (any folder is fine)
# 2. cd into your exercises folder for this module and run echo env.py >> .gitignore
# 3. Create a function named get_db_url. It should accept a username, hostname, password, and database name and return a url connection string formatted like in the example at the start of this lesson.

# %%
def get_db_url(username, hostname, password, database):
    return f'mysql+pymysql://{username}:{password}@{hostname}/{database}'

# %% [markdown]
# 4. Use your function to obtain a connection to the employees database.

# %%
import pandas as pd
import numpy as np
from env import hostname, username, password
url = get_db_url(username, hostname, password, 'employees')

# %%
pd.read_sql('SELECT * FROM employees LIMIT 5 OFFSET 50', url)
# Out:
#    emp_no  birth_date first_name  last_name gender   hire_date
# 0   10051  1953-07-28   Hidefumi      Caine      M  1992-10-15
# 1   10052  1961-02-26     Heping     Nitsch      M  1988-05-21
# 2   10053  1954-09-13     Sanjiv   Zschoche      F  1986-02-04
# 3   10054  1957-04-04     Mayumi  Schueller      M  1995-03-13
# 4   10055  1956-06-06     Georgy     Dredge      M  1992-04-27

# %% [markdown]
# 5. Once you have successfully run a query:
#
#     a. Intentionally make a typo in the database url. What kind of error message do you see?

# %%
#url = get_db_url(username, hostname, password, 'employs')
# misspelled database does not give an error
#url = get_db_url(username, hostname, passwrd, 'employees')
# misspelled variable gives me 'is not defined' error

# %% [markdown]
#    b. Intentionally make an error in your SQL query. What does the error message look like?

# %%
#pd.read_sql('SELECT * FROM employees LIMIT 5 OSET 50', url)
# misspelling 'offset' on the sql query gives a "Programming Error"

# %% [markdown]
# 6. Read the employees and titles tables into two separate DataFrames.

# %%
employees = pd.read_sql('SELECT * FROM employees', url)
employees.head()
# Out:
#    emp_no  birth_date first_name last_name gender   hire_date
# 0   10001  1953-09-02     Georgi   Facello      M  1986-06-26
# 1   10002  1964-06-02    Bezalel    Simmel      F  1985-11-21
# 2   10003  1959-12-03      Parto   Bamford      M  1986-08-28
# 3   10004  1954-05-01  Chirstian   Koblick      M  1986-12-01
# 4   10005  1955-01-21    Kyoichi  Maliniak      M  1989-09-12

# %%
titles = pd.read_sql('SELECT * FROM titles', url)
titles.head()
# Out:
#    emp_no            title   from_date     to_date
# 0   10001  Senior Engineer  1986-06-26  9999-01-01
# 1   10002            Staff  1996-08-03  9999-01-01
# 2   10003  Senior Engineer  1995-12-03  9999-01-01
# 3   10004         Engineer  1986-12-01  1995-12-01
# 4   10004  Senior Engineer  1995-12-01  9999-01-01

# %% [markdown]
# 7. How many rows and columns do you have in each DataFrame? Is that what you expected?

# %%
employees.shape, titles.shape
print('employees has', employees.shape, '\nand titles has', titles.shape)
# Out:
# employees has (300024, 6)
# and titles has (443308, 4)

# %% [markdown]
# 8. Display the summary statistics for each DataFrame.

# %%
employees.describe()
# Out:
#               emp_no
# count  300024.000000
# mean   253321.763392
# std    161828.235540
# min     10001.000000
# 25%     85006.750000
# 50%    249987.500000
# 75%    424993.250000
# max    499999.000000

# %%
titles.describe()
# Out:
#               emp_no
# count  443308.000000
# mean   253075.034430
# std    161853.292613
# min     10001.000000
# 25%     84855.750000
# 50%    249847.500000
# 75%    424891.250000
# max    499999.000000

# %% [markdown]
# 9. How many unique titles are in the titles DataFrame?

# %%
pd.unique(titles.title).size
# Out:
# 7

# %% [markdown]
# 10. What is the oldest date in the to_date column?

# %%
print(titles.to_date.min())
# Out:
# 1985-03-01

# %% [markdown]
# 11. What is the most recent date in the to_date column?

# %%
print(titles.to_date.max())
# Out:
# 9999-01-01

# %%
#most recent that is not 9999-01-01
print(titles.to_date[titles.to_date != titles.to_date.max()].max())
# Out:
# 2002-08-01

# %% [markdown]
# ## Exercises II
#
# 1. Copy the users and roles DataFrames from the examples above.

# %%
# Create the roles DataFrame

roles = pd.DataFrame({
    'id': [1, 2, 3, 4],
    'name': ['admin', 'author', 'reviewer', 'commenter']
})
roles
# Out:
#    id       name
# 0   1      admin
# 1   2     author
# 2   3   reviewer
# 3   4  commenter

# %%
# Create the users DataFrame.

users = pd.DataFrame({
    'id': [1, 2, 3, 4, 5, 6],
    'name': ['bob', 'joe', 'sally', 'adam', 'jane', 'mike'],
    'role_id': [1, 2, 3, 3, np.nan, np.nan]
})
users
# Out:
#    id   name  role_id
# 0   1    bob      1.0
# 1   2    joe      2.0
# 2   3  sally      3.0
# 3   4   adam      3.0
# 4   5   jane      NaN
# 5   6   mike      NaN

# %% [markdown]
# 2. What is the result of using a right join on the DataFrames?

# %%
users.merge(roles, left_on='role_id', right_on='id',how='right', indicator=True)
# Out:
#    id_x name_x  role_id  id_y     name_y      _merge
# 0   1.0    bob      1.0     1      admin        both
# 1   2.0    joe      2.0     2     author        both
# 2   3.0  sally      3.0     3   reviewer        both
# 3   4.0   adam      3.0     3   reviewer        both
# 4   NaN    NaN      NaN     4  commenter  right_only

# %% [markdown]
# 3. What is the result of using an outer join on the DataFrames?

# %%
users.merge(roles, left_on='role_id', right_on='id',how='outer', indicator=True)
# Out:
#    id_x name_x  role_id  id_y     name_y      _merge
# 0   1.0    bob      1.0   1.0      admin        both
# 1   2.0    joe      2.0   2.0     author        both
# 2   3.0  sally      3.0   3.0   reviewer        both
# 3   4.0   adam      3.0   3.0   reviewer        both
# 4   5.0   jane      NaN   NaN        NaN   left_only
# 5   6.0   mike      NaN   NaN        NaN   left_only
# 6   NaN    NaN      NaN   4.0  commenter  right_only

# %% [markdown]
# 4. What happens if you drop the foreign keys from the DataFrames and try to merge them?

# %%
users.merge(roles, how='outer', indicator=True)
# Out:
#    id       name  role_id      _merge
# 0   1        bob      1.0   left_only
# 1   2        joe      2.0   left_only
# 2   3      sally      3.0   left_only
# 3   4       adam      3.0   left_only
# 4   5       jane      NaN   left_only
# 5   6       mike      NaN   left_only
# 6   1      admin      NaN  right_only
# 7   2     author      NaN  right_only
# 8   3   reviewer      NaN  right_only
# 9   4  commenter      NaN  right_only

# %% [markdown]
# 5. Load the mpg dataset from PyDataset.

# %%
from pydataset import data
data('mpg', show_doc=True) 
mpg = data('mpg') 
# load the dataset and store it in a variable
mpg
# view the documentation for the dataset
# Out:
# mpg
#
# PyDataset Documentation (adopted from R Documentation. The displayed examples are in R)
#
# ## Fuel economy data from 1999 and 2008 for 38 popular models of car
#
# ### Description
#
# This dataset contains a subset of the fuel economy data that the EPA makes
# available on http://fueleconomy.gov. It contains only models which had a new
# release every year between 1999 and 2008 - this was used as a proxy for the
# popularity of the car.
#
# ### Usage
#
#     data(mpg)
#
# ### Format
#
# A data frame with 234 rows and 11 variables
#
# ### Details
#
#   * manufacturer.
#
#   * model.
#
#   * displ. engine displacement, in litres
#
#   * year.
#
#   * cyl. number of cylinders
#
#   * trans. type of transmission
#
#   * drv. f = front-wheel drive, r = rear wheel drive, 4 = 4wd
#
#   * cty. city miles per gallon
#
#   * hwy. highway miles per gallon
#
#   * fl.
#
#   * class.
#     manufacturer   model  displ  year  cyl       trans drv  cty  hwy fl  \
# ...

# %% [markdown]
# 6. Output and read the documentation for the mpg dataset.

# %%
data('mpg', show_doc=True)
# Out:
# mpg
#
# PyDataset Documentation (adopted from R Documentation. The displayed examples are in R)
#
# ## Fuel economy data from 1999 and 2008 for 38 popular models of car
#
# ### Description
#
# This dataset contains a subset of the fuel economy data that the EPA makes
# available on http://fueleconomy.gov. It contains only models which had a new
# release every year between 1999 and 2008 - this was used as a proxy for the
# popularity of the car.
#
# ### Usage
#
#     data(mpg)
#
# ### Format
#
# A data frame with 234 rows and 11 variables
#
# ### Details
#
#   * manufacturer.
#
#   * model.
#
#   * displ. engine displacement, in litres
#
#   * year.
#
#   * cyl. number of cylinders
#
#   * trans. type of transmission
#
#   * drv. f = front-wheel drive, r = rear wheel drive, 4 = 4wd
#
#   * cty. city miles per gallon
#
#   * hwy. highway miles per gallon
#
#   * fl.
#
#   * class.

# %% [markdown]
# 7. How many rows and columns are in the dataset?

# %%
print(mpg.shape)
# Out:
# (234, 11)

# %% [markdown]
# 8. Check out your column names and perform any cleanup you may want on them.

# %%
mpg.columns
#check the columns names
# Out:
# Index(['manufacturer', 'model', 'displ', 'year', 'cyl', 'trans', 'drv', 'cty',
#        'hwy', 'fl', 'class'],
#       dtype='object')

# %%
mpg = mpg.rename(columns = {'displ' : 'displacement', 'cyl' : 'cylinders', 'drv' : 'drive', 'cty' : 'city', 'hwy' : 'highway',})
mpg.columns
# Out:
# Index(['manufacturer', 'model', 'displacement', 'year', 'cylinders', 'trans',
#        'drive', 'city', 'highway', 'fl', 'class'],
#       dtype='object')

# %% [markdown]
# 9. Display the summary statistics for the dataset.

# %%
mpg.describe().round(2)
# Out:
#        displacement     year  cylinders    city  highway
# count        234.00   234.00     234.00  234.00   234.00
# mean           3.47  2003.50       5.89   16.86    23.44
# std            1.29     4.51       1.61    4.26     5.95
# min            1.60  1999.00       4.00    9.00    12.00
# 25%            2.40  1999.00       4.00   14.00    18.00
# 50%            3.30  2003.50       6.00   17.00    24.00
# 75%            4.60  2008.00       8.00   19.00    27.00
# max            7.00  2008.00       8.00   35.00    44.00

# %% [markdown]
# 10. How many different manufacturers are there?

# %%
#unique will return a list of unique manufacturers and size measures how many are in there
mpg.manufacturer.unique().size
# 15 different manufacturers
# Out:
# 15

# %% [markdown]
# 11. How many different models are there?

# %%
#unique will return a list unique of models and size will measure how many are in the list
mpg.model.unique().size
#38 different models
# Out:
# 38

# %% [markdown]
# 12. Create a column named mileage_difference like you did in the DataFrames exercises; this column should contain the difference between highway and city mileage for each car.

# %%
# name column equals operation to obtain the difference
mpg['mileage_difference'] = mpg.highway - mpg.city 
mpg
# Out:
#     manufacturer   model  displacement  year  cylinders       trans drive  \
# 1           audi      a4           1.8  1999          4    auto(l5)     f
# 2           audi      a4           1.8  1999          4  manual(m5)     f
# 3           audi      a4           2.0  2008          4  manual(m6)     f
# 4           audi      a4           2.0  2008          4    auto(av)     f
# 5           audi      a4           2.8  1999          6    auto(l5)     f
# ..           ...     ...           ...   ...        ...         ...   ...
# 230   volkswagen  passat           2.0  2008          4    auto(s6)     f
# 231   volkswagen  passat           2.0  2008          4  manual(m6)     f
# 232   volkswagen  passat           2.8  1999          6    auto(l5)     f
# 233   volkswagen  passat           2.8  1999          6  manual(m5)     f
# 234   volkswagen  passat           3.6  2008          6    auto(s6)     f
#
#      city  highway fl    class  mileage_difference  average_mileage  \
# ...

# %% [markdown]
# 13. Create a column named average_mileage like you did in the DataFrames exercises; this is the mean of the city and highway mileage.

# %%
# name column equals operation to obtain average
mpg["average_mileage"] = (mpg.highway + mpg.city) / 2
mpg
# Out:
#     manufacturer   model  displacement  year  cylinders       trans drive  \
# 1           audi      a4           1.8  1999          4    auto(l5)     f
# 2           audi      a4           1.8  1999          4  manual(m5)     f
# 3           audi      a4           2.0  2008          4  manual(m6)     f
# 4           audi      a4           2.0  2008          4    auto(av)     f
# 5           audi      a4           2.8  1999          6    auto(l5)     f
# ..           ...     ...           ...   ...        ...         ...   ...
# 230   volkswagen  passat           2.0  2008          4    auto(s6)     f
# 231   volkswagen  passat           2.0  2008          4  manual(m6)     f
# 232   volkswagen  passat           2.8  1999          6    auto(l5)     f
# 233   volkswagen  passat           2.8  1999          6  manual(m5)     f
# 234   volkswagen  passat           3.6  2008          6    auto(s6)     f
#
#      city  highway fl    class  mileage_difference  average_mileage  \
# ...

# %% [markdown]
# 14. Create a new column on the mpg dataset named is_automatic that holds boolean values denoting whether the car has an automatic transmission.

# %%
# look at the names used under transmission
mpg.trans.unique()
# Out:
# array(['auto(l5)', 'manual(m5)', 'manual(m6)', 'auto(av)', 'auto(s6)',
#        'auto(l4)', 'auto(l3)', 'auto(l6)', 'auto(s5)', 'auto(s4)'],
#       dtype=object)

# %%
# using "startswith(auto)" should return the expected output
mpg['is_automatic'] = mpg['trans'].str.startswith('auto')
mpg
# Out:
#     manufacturer   model  displacement  year  cylinders       trans drive  \
# 1           audi      a4           1.8  1999          4    auto(l5)     f
# 2           audi      a4           1.8  1999          4  manual(m5)     f
# 3           audi      a4           2.0  2008          4  manual(m6)     f
# 4           audi      a4           2.0  2008          4    auto(av)     f
# 5           audi      a4           2.8  1999          6    auto(l5)     f
# ..           ...     ...           ...   ...        ...         ...   ...
# 230   volkswagen  passat           2.0  2008          4    auto(s6)     f
# 231   volkswagen  passat           2.0  2008          4  manual(m6)     f
# 232   volkswagen  passat           2.8  1999          6    auto(l5)     f
# 233   volkswagen  passat           2.8  1999          6  manual(m5)     f
# 234   volkswagen  passat           3.6  2008          6    auto(s6)     f
#
#      city  highway fl    class  mileage_difference  average_mileage  \
# ...

# %% [markdown]
# 15. Using the mpg dataset, find out which which manufacturer has the best miles per gallon on average?

# %%
# get the average mile grouped by manufacturer
manufacturer_mean = mpg.groupby('manufacturer').average_mileage.mean()
# get the largest average as an output
manufacturer_mean.nlargest(1, keep='all')
# Out:
# manufacturer
# honda    28.5
# Name: average_mileage, dtype: float64

# %% [markdown]
# 16. Do automatic or manual cars have better miles per gallon?

# %%
# get the average mileage grouped by automatic or not
transmission_mean = mpg.groupby('is_automatic').average_mileage.mean()
# largest average
transmission_mean.nlargest(1)
# manual trnasmission gives better mileage
# Out:
# is_automatic
# False    22.227273
# Name: average_mileage, dtype: float64

# %% [markdown]
# ### Exercises III
#
# 1. Use your get_db_url function to help you explore the data from the chipotle database.

# %%
url= get_db_url(username,hostname, password, 'chipotle')

# %% [markdown]
# 2. What is the total price for each order?

# %%
chipotle = pd.read_sql('SELECT * FROM orders', url)
chipotle
# Out:
#         id  order_id  quantity                              item_name  \
# 0        1         1         1           Chips and Fresh Tomato Salsa
# 1        2         1         1                                   Izze
# 2        3         1         1                       Nantucket Nectar
# 3        4         1         1  Chips and Tomatillo-Green Chili Salsa
# 4        5         2         2                           Chicken Bowl
# ...    ...       ...       ...                                    ...
# 4617  4618      1833         1                          Steak Burrito
# 4618  4619      1833         1                          Steak Burrito
# 4619  4620      1834         1                     Chicken Salad Bowl
# 4620  4621      1834         1                     Chicken Salad Bowl
# 4621  4622      1834         1                     Chicken Salad Bowl
#
#                                                                      choice_description  \
# ...

# %%
#remove "$" and make a float
chipotle['item_price'] = chipotle.item_price.str.strip('$').astype('float')
chipotle
# Out:
#         id  order_id  quantity                              item_name  \
# 0        1         1         1           Chips and Fresh Tomato Salsa
# 1        2         1         1                                   Izze
# 2        3         1         1                       Nantucket Nectar
# 3        4         1         1  Chips and Tomatillo-Green Chili Salsa
# 4        5         2         2                           Chicken Bowl
# ...    ...       ...       ...                                    ...
# 4617  4618      1833         1                          Steak Burrito
# 4618  4619      1833         1                          Steak Burrito
# 4619  4620      1834         1                     Chicken Salad Bowl
# 4620  4621      1834         1                     Chicken Salad Bowl
# 4621  4622      1834         1                     Chicken Salad Bowl
#
#                                                                      choice_description  \
# ...

# %%
# get total_price for eac item by multiplying quantity times item_price
chipotle['total_price'] = chipotle.quantity * chipotle.item_price
chipotle
# Out:
#         id  order_id  quantity                              item_name  \
# 0        1         1         1           Chips and Fresh Tomato Salsa
# 1        2         1         1                                   Izze
# 2        3         1         1                       Nantucket Nectar
# 3        4         1         1  Chips and Tomatillo-Green Chili Salsa
# 4        5         2         2                           Chicken Bowl
# ...    ...       ...       ...                                    ...
# 4617  4618      1833         1                          Steak Burrito
# 4618  4619      1833         1                          Steak Burrito
# 4619  4620      1834         1                     Chicken Salad Bowl
# 4620  4621      1834         1                     Chicken Salad Bowl
# 4621  4622      1834         1                     Chicken Salad Bowl
#
#                                                                      choice_description  \
# ...

# %%
#getting the order ids
tot_price_ord_id = chipotle.groupby('order_id').total_price.sum()
tot_price_ord_id
# Out:
# order_id
# 1       11.56
# 2       33.96
# 3       12.67
# 4       21.00
# 5       13.70
#         ...
# 1830    23.00
# 1831    12.90
# 1832    13.20
# 1833    23.50
# 1834    28.75
# Name: total_price, Length: 1834, dtype: float64

# %% [markdown]
# 3. What are the most popular 3 items?

# %%
#show the 3 largest item quantities grouped by item name 
chipotle.groupby('item_name').quantity.sum().nlargest(3, keep='all')
# Out:
# item_name
# Chicken Bowl           761
# Chicken Burrito        591
# Chips and Guacamole    506
# Name: quantity, dtype: int64

# %% [markdown]
# 4. Which item has produced the most revenue?

# %%
#show the largest sum of total price grouped by item name
chipotle.groupby('item_name').total_price.sum().nlargest(1, keep='all')
# Out:
# item_name
# Chicken Bowl    8044.63
# Name: total_price, dtype: float64

# %% [markdown]
# 5. Join the employees and titles DataFrames together.

# %%
# verify items listed on employees table
employees.head()
# Out:
#    emp_no  birth_date first_name last_name gender   hire_date
# 0   10001  1953-09-02     Georgi   Facello      M  1986-06-26
# 1   10002  1964-06-02    Bezalel    Simmel      F  1985-11-21
# 2   10003  1959-12-03      Parto   Bamford      M  1986-08-28
# 3   10004  1954-05-01  Chirstian   Koblick      M  1986-12-01
# 4   10005  1955-01-21    Kyoichi  Maliniak      M  1989-09-12

# %%
#verify items listed on titles table
titles.head()

#emp_no is the joining
# Out:
#    emp_no            title   from_date     to_date
# 0   10001  Senior Engineer  1986-06-26  9999-01-01
# 1   10002            Staff  1996-08-03  9999-01-01
# 2   10003  Senior Engineer  1995-12-03  9999-01-01
# 3   10004         Engineer  1986-12-01  1995-12-01
# 4   10004  Senior Engineer  1995-12-01  9999-01-01

# %%
#join employees table with titles tables using/ON emp_no
employees_with_titles = employees.merge(titles, on='emp_no')
employees_with_titles
# Out:
#         emp_no  birth_date first_name last_name gender   hire_date  \
# 0        10001  1953-09-02     Georgi   Facello      M  1986-06-26
# 1        10002  1964-06-02    Bezalel    Simmel      F  1985-11-21
# 2        10003  1959-12-03      Parto   Bamford      M  1986-08-28
# 3        10004  1954-05-01  Chirstian   Koblick      M  1986-12-01
# 4        10004  1954-05-01  Chirstian   Koblick      M  1986-12-01
# ...        ...         ...        ...       ...    ...         ...
# 443303  499997  1961-08-03    Berhard    Lenart      M  1986-04-21
# 443304  499997  1961-08-03    Berhard    Lenart      M  1986-04-21
# 443305  499998  1956-09-05   Patricia   Breugel      M  1993-10-13
# 443306  499998  1956-09-05   Patricia   Breugel      M  1993-10-13
# 443307  499999  1958-05-01     Sachin   Tsukuda      M  1997-11-30
#
#                   title   from_date     to_date
# 0       Senior Engineer  1986-06-26  9999-01-01
# 1                 Staff  1996-08-03  9999-01-01
# ...

# %% [markdown]
# 6. For each title, find the hire date of the employee that was hired most recently with that title.

# %%
employees_with_titles.groupby('title').hire_date.max()
# Out:
# title
# Assistant Engineer    1999-12-24
# Engineer              2000-01-28
# Manager               1992-02-05
# Senior Engineer       2000-01-01
# Senior Staff          2000-01-13
# Staff                 2000-01-12
# Technique Leader      1999-12-31
# Name: hire_date, dtype: object

# %% [markdown]
# 7. Write the code necessary to create a cross tabulation of the number of titles by department. (Hint: this will involve a combination of SQL code to pull the necessary data and python/pandas code to perform the manipulations.)

# %%
url = get_db_url(username, hostname, password, 'employees')
# 
sql = '''
SELECT DISTINCT *
	FROM employees e
    JOIN titles t USING(emp_no)
    JOIN dept_emp de USING(emp_no)
    JOIN departments d USING(dept_no)
    WHERE
    t.to_date > now() AND de.to_date > now();
'''

df = pd.read_sql(sql, url)

# %%
#verify the information that came through
df.head()
# Out:
#   dept_no  emp_no  birth_date first_name    last_name gender   hire_date  \
# 0    d009   10038  1960-07-20       Huan        Lortz      M  1989-09-20
# 1    d009   10049  1961-04-24      Basil       Tramer      F  1992-05-04
# 2    d009   10060  1961-10-15   Breannda  Billingsley      M  1987-11-02
# 3    d009   10088  1954-02-25   Jungsoon     Syrzycki      F  1988-09-02
# 4    d009   10112  1963-08-13   Yuichiro        Swick      F  1985-10-08
#
#           title   from_date     to_date   from_date     to_date  \
# 0  Senior Staff  1996-09-20  9999-01-01  1989-09-20  9999-01-01
# 1  Senior Staff  2000-05-04  9999-01-01  1992-05-04  9999-01-01
# 2  Senior Staff  1996-05-28  9999-01-01  1992-11-11  9999-01-01
# 3  Senior Staff  1993-09-02  9999-01-01  1992-03-21  9999-01-01
# 4         Staff  1998-05-01  9999-01-01  1998-05-01  9999-01-01
#
#           dept_name
# 0  Customer Service
# 1  Customer Service
# 2  Customer Service
# 3  Customer Service
# 4  Customer Service

# %%
pd.crosstab(df.title, df.dept_name)
# Out:
# dept_name           Customer Service  Development  Finance  Human Resources  \
# title
# Assistant Engineer                68         1652        0                0
# Engineer                         627        14040        0                0
# Manager                            1            1        1                1
# Senior Engineer                 1790        38816        0                0
# Senior Staff                   11268         1085     9545             9824
# Staff                           3574          315     2891             3073
# Technique Leader                 241         5477        0                0
#
# dept_name           Marketing  Production  Quality Management  Research  Sales
# title
# Assistant Engineer          0        1402                 389        77      0
# Engineer                    0       12081                3405       830      0
# Manager                     1           1                   1         1      1
# ...
